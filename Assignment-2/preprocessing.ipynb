# %%
from importlib import import_module
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv('jumlah-sekolah-sd-di-dki-jakarta-per-kecamatan.csv')
# print(dataset)
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -3].values
print("data X : ", X)

# Menghilangkan missing value
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer.fit(X)
X = imputer.transform(X)
print(imputer.transform(X))

# Encoding data kategori
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0,1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)

# Melakukan split dataset menjadi Training set dan Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)
print("x_train : ", X_train)
print("x_test : ", X_test)
print("y_train : ", y_train)
print("y_test : ", y_test)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 5:] = sc.fit_transform(X_train[:, 5:].reshape(1, -1))
X_test[:, 5:] = sc.fit_transform(X_test[:, 5:].reshape(1, -1))
print(X_test)
print(X_train)
# Out:
# data X :  [['Jakarta Pusat' 'Tanah Abang' 33]
#  ['Jakarta Pusat' 'Menteng' 17]
#  ['Jakarta Pusat' 'Senen' 39]
#  ['Jakarta Pusat' 'Johar Baru' 35]
#  ['Jakarta Pusat' 'Cempaka Putih' 25]
#  ['Jakarta Pusat' 'Kemayoran' 70]
#  ['Jakarta Pusat' 'Sawah Besar' 25]
#  ['Jakarta Pusat' 'Gambir' 32]
#  ['Jakarta Utara' 'Penjaringan' 39]
#  ['Jakarta Utara' 'Pademangan' 27]
#  ['Jakarta Utara' 'Tanjung Priok' 55]
#  ['Jakarta Utara' 'Koja' 71]
#  ['Jakarta Utara' 'Kelapa Gading' 17]
#  ['Jakarta Utara' 'Cilincing' 60]
#  ['Jakarta Barat' 'Kembangan' 57]
#  ['Jakarta Barat' 'Kebon Jeruk' 68]
#  ['Jakarta Barat' 'Palmerah' 56]
#  ['Jakarta Barat' 'Grogol Petamburan' 45]
#  ['Jakarta Barat' 'Tambora' 35]
#  ['Jakarta Barat' 'Taman Sari' 30]
#  ['Jakarta Barat' 'Cengkareng' 92]
#  ['Jakarta Barat' 'Kalideres' 73]
#  ['Jakarta Selatan' 'Jagakarsa' 62]
#  ['Jakarta Selatan' 'Pasar Minggu' 65]
#  ['Jakarta Selatan' 'Cilandak' 46]
#  ['Jakarta Selatan' 'Pesanggrahan' 48]
#  ['Jakarta Selatan' 'Kebayoran Lama' 82]
#  ['Jakarta Selatan' 'Kebayoran Baru' 42]
#  ['Jakarta Selatan' 'Mampang Prapatan' 36]
#  ['Jakarta Selatan' 'Pancoran' 44]
#  ['Jakarta Selatan' 'Tebet' 61]
#  ['Jakarta Selatan' ' Setia Budi' 35]
#  ['Jakarta Timur' ' Pasar Rebo' 59]
#  ['Jakarta Timur' ' Ciracas' 55]
#  ['Jakarta Timur' ' Cipayung' 55]
#  ['Jakarta Timur' ' Makasar' 48]
#  ['Jakarta Timur' ' Kramat Jati' 75]
#  ['Jakarta Timur' ' Jatinegara' 74]
#  ['Jakarta Timur' ' Duren Sawit' 98]
#  ['Jakarta Timur' ' Cakung' 88]
#  ['Jakarta Timur' ' Pulo Gadung' 66]
#  ['Jakarta Timur' ' Matraman' 54]
#  ['Kepulauan Seribu' ' Kepulauan Seribu Selatan' 7]
#  ['Kepulauan Seribu' ' Kepulauan Seribu Utara' 7]]
# [['Jakarta Pusat' 'Tanah Abang' 33]
#  ['Jakarta Pusat' 'Menteng' 17]
#  ['Jakarta Pusat' 'Senen' 39]
#  ['Jakarta Pusat' 'Johar Baru' 35]
#  ['Jakarta Pusat' 'Cempaka Putih' 25]
#  ['Jakarta Pusat' 'Kemayoran' 70]
#  ['Jakarta Pusat' 'Sawah Besar' 25]
#  ['Jakarta Pusat' 'Gambir' 32]
#  ['Jakarta Utara' 'Penjaringan' 39]
#  ['Jakarta Utara' 'Pademangan' 27]
#  ['Jakarta Utara' 'Tanjung Priok' 55]
#  ['Jakarta Utara' 'Koja' 71]
#  ['Jakarta Utara' 'Kelapa Gading' 17]
#  ['Jakarta Utara' 'Cilincing' 60]
#  ['Jakarta Barat' 'Kembangan' 57]
#  ['Jakarta Barat' 'Kebon Jeruk' 68]
#  ['Jakarta Barat' 'Palmerah' 56]
#  ['Jakarta Barat' 'Grogol Petamburan' 45]
#  ['Jakarta Barat' 'Tambora' 35]
#  ['Jakarta Barat' 'Taman Sari' 30]
#  ['Jakarta Barat' 'Cengkareng' 92]
#  ['Jakarta Barat' 'Kalideres' 73]
#  ['Jakarta Selatan' 'Jagakarsa' 62]
#  ['Jakarta Selatan' 'Pasar Minggu' 65]
#  ['Jakarta Selatan' 'Cilandak' 46]
#  ['Jakarta Selatan' 'Pesanggrahan' 48]
#  ['Jakarta Selatan' 'Kebayoran Lama' 82]
#  ['Jakarta Selatan' 'Kebayoran Baru' 42]
#  ['Jakarta Selatan' 'Mampang Prapatan' 36]
#  ['Jakarta Selatan' 'Pancoran' 44]
#  ['Jakarta Selatan' 'Tebet' 61]
#  ['Jakarta Selatan' ' Setia Budi' 35]
#  ['Jakarta Timur' ' Pasar Rebo' 59]
#  ['Jakarta Timur' ' Ciracas' 55]
#  ['Jakarta Timur' ' Cipayung' 55]
#  ['Jakarta Timur' ' Makasar' 48]
#  ['Jakarta Timur' ' Kramat Jati' 75]
#  ['Jakarta Timur' ' Jatinegara' 74]
#  ['Jakarta Timur' ' Duren Sawit' 98]
#  ['Jakarta Timur' ' Cakung' 88]
#  ['Jakarta Timur' ' Pulo Gadung' 66]
#  ['Jakarta Timur' ' Matraman' 54]
#  ['Kepulauan Seribu' ' Kepulauan Seribu Selatan' 7]
#  ['Kepulauan Seribu' ' Kepulauan Seribu Utara' 7]]
#   (0, 1)	1.0
#   (0, 47)	1.0
#   (0, 50)	33.0
#   (1, 1)	1.0
#   (1, 36)	1.0
#   (1, 50)	17.0
#   (2, 1)	1.0
#   (2, 44)	1.0
#   (2, 50)	39.0
#   (3, 1)	1.0
#   (3, 26)	1.0
#   (3, 50)	35.0
#   (4, 1)	1.0
#   (4, 19)	1.0
#   (4, 50)	25.0
#   (5, 1)	1.0
#   (5, 32)	1.0
#   (5, 50)	70.0
#   (6, 1)	1.0
#   (6, 43)	1.0
#   (6, 50)	25.0
#   (7, 1)	1.0
#   (7, 23)	1.0
#   (7, 50)	32.0
#   (8, 4)	1.0
#   :	:
#   (35, 50)	48.0
#   (36, 3)	1.0
#   (36, 13)	1.0
#   (36, 50)	75.0
#   (37, 3)	1.0
#   (37, 10)	1.0
#   (37, 50)	74.0
#   (38, 3)	1.0
#   (38, 9)	1.0
#   (38, 50)	98.0
#   (39, 3)	1.0
#   (39, 6)	1.0
#   (39, 50)	88.0
#   (40, 3)	1.0
#   (40, 17)	1.0
#   (40, 50)	66.0
#   (41, 3)	1.0
#   (41, 15)	1.0
#   (41, 50)	54.0
#   (42, 5)	1.0
#   (42, 11)	1.0
#   (42, 50)	7.0
#   (43, 5)	1.0
#   (43, 12)	1.0
#   (43, 50)	7.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-7a1ae5e212d0> in <module>()
#      25 # Melakukan split dataset menjadi Training set dan Test set
#      26 from sklearn.model_selection import train_test_split
# ---> 27 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=1)
#      28 print("x_train : ", x_train)
#      29 print("x_test : ", x_test)
#
# NameError: name 'x' is not defined
